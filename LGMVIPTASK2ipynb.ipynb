# %% [markdown]
# <a href="https://colab.research.google.com/github/NirajShaha/LGMVIPTASK2-DA/blob/main/LGMVIPTASK2ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LetsGrowMore Virtual Internship Program ( March 2022 - April 2022 )
#
# Author : Niraj Shaha
#
# Task 2 : Image to Pencil Sketch with Python
#
# Level : Beginner
# In these task, we have to convert a given image into its pencil sketch using python. In these we use CV ( Computer Vision ) library and Pillow module for the Image Processing.

# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import cv2
from PIL import Image
from IPython.display import display

# %% [markdown]
# Loading the Image

# %%
img  =  cv2.imread("/content/sample_data/Image.jpg")
img = cv2.resize(img,(200,300))
rgb_img =  cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
display(Image.fromarray(rgb_img))
# Out:
# <PIL.Image.Image image mode=RGB size=200x300 at 0x7FB150FC9990>

# %% [markdown]
# Converting Image to Greyscale Image

# %%
greyscale_img =  cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(greyscale_img))
# Out:
# <PIL.Image.Image image mode=L size=200x300 at 0x7FB150EE4950>

# %% [markdown]
# Converting the Image to Negative Image

# %%
neg_img = cv2.bitwise_not(greyscale_img)
display(Image.fromarray(neg_img))
# Out:
# <PIL.Image.Image image mode=L size=200x300 at 0x7FB150EE9410>

# %% [markdown]
# Smoothening the Image

# %%
smooth_img = cv2.GaussianBlur(neg_img, (5,5), 0, 0)
display(Image.fromarray(smooth_img))
# Out:
# <PIL.Image.Image image mode=L size=200x300 at 0x7FB150EF4D50>

# %% [markdown]
# Converting Image into Pencil Sketch

# %%
sketch_img = 255 - smooth_img
sketch = cv2.divide(greyscale_img, sketch_img, scale=250.0)
display(Image.fromarray(sketch))
# Out:
# <PIL.Image.Image image mode=L size=200x300 at 0x7FB150EE9490>

# %% [markdown]
# Comparision between Original Image and Pencil Sketch

# %%
rgb_img =  cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
display(Image.fromarray(rgb_img))
display(Image.fromarray(sketch))
# Out:
# <PIL.Image.Image image mode=RGB size=200x300 at 0x7FB150ED1F10>
# <PIL.Image.Image image mode=L size=200x300 at 0x7FB150ED1990>
